# %% [markdown]
# <a href="https://colab.research.google.com/github/herotam77/PortfolioProjects/blob/main/Toyota.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
car =pd.read_csv("ToyotaCorolla.csv",encoding='latin-1',sep=',')
car.drop("Id",axis=1,inplace=True)
car.head()
# Out:
#                                             Model  Price  Age_08_04  \
# 0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color   Color  ...  \
# 0         10      2002  46986    Diesel  90          1    Blue  ...
# 1         10      2002  72937    Diesel  90          1  Silver  ...
# 2          9      2002  41711    Diesel  90          1    Blue  ...
# 3          7      2002  48000    Diesel  90          0   Black  ...
# 4          3      2002  38500    Diesel  90          0   Black  ...
#
#    Central_Lock  Powered_Windows  Power_Steering  Radio  Mistlamps  \
# 0             1                1               1      0          0
# ...

# %%
# car =car.sample(100)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1431 entries, 0 to 1430
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model             1431 non-null   object
#  1   Price             1431 non-null   int64
#  2   Age_08_04         1431 non-null   int64
#  3   Mfg_Month         1431 non-null   int64
#  4   Mfg_Year          1431 non-null   int64
#  5   KM                1431 non-null   int64
#  6   Fuel_Type         1431 non-null   object
#  7   HP                1431 non-null   int64
#  8   Met_Color         1431 non-null   int64
#  9   Color             1431 non-null   object
#  10  Automatic         1431 non-null   int64
#  11  cc                1431 non-null   int64
#  12  Doors             1431 non-null   int64
#  13  Cylinders         1431 non-null   int64
#  14  Gears             1431 non-null   int64
#  15  Quarterly_Tax     1431 non-null   int64
# ...

# %%
car.head(100)
# Out:
#                                                 Model  Price  Age_08_04  \
# 0       TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1       TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2       TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3       TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4         TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# ..                                                ...    ...        ...
# 95  TOYOTA Corolla 2.0 D4D Linea Sol 3 Doors 2/3-D...  19950         17
# 96   TOYOTA Corolla 1.4 16V VVT I 3DR TERRA COMFOR...  15950         19
# 97  TOYOTA Corolla 1.4 16V VVT I 3DR TERRA COMFORT...  15950         19
# 98     TOYOTA Corolla 1.6 16V VVT I 3DR SOL 2/3-Doors  18750         11
# 99  TOYOTA Corolla 1.4 16V VVT I 3DR TERRA COMFORT...  17450         18
#
#     Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color   Color  ...  \
# ...

# %%
car.isnull().sum()
# Out:
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Color               0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %%
car['Model'].value_counts().head(1000)
# Out:
# TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-Doors         107
# TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-Doors          83
# TOYOTA Corolla 1.6 16V LIFTB LINEA LUNA 4/5-Doors            78
# TOYOTA Corolla 1.6 16V LIFTB LINEA TERRA 4/5-Doors           70
# TOYOTA Corolla 1.6 16V SEDAN LINEA TERRA 4/5-Doors           43
#                                                            ...
# TOYOTA Corolla 2.0 D4D 90 5DR TERRA 4/5-Doors                 1
#  TOYOTA Corolla 1.6 16V VVT I SEDAN TERRA AUT4 4/5-Doors      1
#  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors                1
# TOYOTA Corolla 1.9 D Linea Terra 2/3-Doors                    1
# TOYOTA Corolla 1.3 Linea Terra 4/5-Doors                      1
# Name: Model, Length: 370, dtype: int64

# %%
import re
text ="TOYOTA Corolla "
re.findall(r'[0-9]',text)
# Out:
# []

# %%
import re
def  extract_engine(text):
    digits =re.findall(r'[0-9]',text)
    if len(digits)==0:
      return 0
    if type(digits)==list:
      return  int(digits[0])
    else:
      return int(digits)

# %%
car['Model'] =car['Model'].map(extract_engine)
car.head()
# Out:
#    Model  Price  Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type  HP  \
# 0      2  13500         23         10      2002  46986    Diesel  90
# 1      2  13750         23         10      2002  72937    Diesel  90
# 2      2  13950         24          9      2002  41711    Diesel  90
# 3      2  14950         26          7      2002  48000    Diesel  90
# 4      2  13750         30          3      2002  38500    Diesel  90
#
#    Met_Color   Color  ...  Central_Lock  Powered_Windows  Power_Steering  \
# 0          1    Blue  ...             1                1               1
# 1          1  Silver  ...             1                0               1
# 2          1    Blue  ...             0                0               1
# 3          0   Black  ...             0                0               1
# 4          0   Black  ...             1                1               1
#
#    Radio  Mistlamps  Sport_Model  Backseat_Divider  Metallic_Rim  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
mylabel =LabelEncoder()
car['Fuel_Type'] =mylabel.fit_transform(car['Fuel_Type'])
car['Color'] =mylabel.fit_transform(car['Color'])
car.head()
# Out:
#    Model  Price  Age_08_04  Mfg_Month  Mfg_Year     KM  Fuel_Type  HP  \
# 0      2  13500         23         10      2002  46986          1  90
# 1      2  13750         23         10      2002  72937          1  90
# 2      2  13950         24          9      2002  41711          1  90
# 3      2  14950         26          7      2002  48000          1  90
# 4      2  13750         30          3      2002  38500          1  90
#
#    Met_Color  Color  ...  Central_Lock  Powered_Windows  Power_Steering  \
# 0          1      2  ...             1                1               1
# 1          1      6  ...             1                0               1
# 2          1      2  ...             0                0               1
# 3          0      1  ...             0                0               1
# 4          0      1  ...             1                1               1
#
#    Radio  Mistlamps  Sport_Model  Backseat_Divider  Metallic_Rim  \
# ...

# %%
new_car =np.array([[1,]])

# %%
y =car['Price'].values
X =car.drop('Price',axis=1).values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (1144, 36)

# %%
from sklearn.preprocessing import MinMaxScaler
myscaler =MinMaxScaler()
X_train =myscaler.fit_transform(X_train)
X_test =myscaler.transform(X_test)

# %%
from sklearn.decomposition import PCA
mypca =PCA(n_components=19)
X_train =mypca.fit_transform(X_train)
X_test =mypca.transform(X_test)
X_train.shape
# Out:
# (1144, 19)

# %%
from sklearn.linear_model import LinearRegression
model =LinearRegression()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.7623938829810912

# %%
import numpy as np
np.sum(mypca.explained_variance_ratio_)
# Out:
# 0.9446751747269573

# %%
mycar='TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-Doors'
mycar.split()[-1].split('-')[0].split('/')[1]
# Out:
# '3'
